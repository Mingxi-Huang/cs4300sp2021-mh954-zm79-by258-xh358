# %%
import pandas as pd
import numpy as np 
from sklearn.naive_bayes import MultinomialNB  
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer,TfidfVectorizer
import nltk
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection   import train_test_split
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer as TFIDF
from pylab import *
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aybnning/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/aybnning/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
f = open('News_Category_Dataset_train.json')
text = f.read()
f.close()
all_list = []
for j in text.split('\n'):
    try:
        all_list.append(eval(j))
    except:
        pass
train = pd.DataFrame(all_list)

# %%
cachedStopWords = stopwords.words("english")

# %%
#train the model using categorized data and news titles
def removeStopword(x):
    text = x['headline']
    return  str(' '.join([lemmatizer.lemmatize(word).lower() for word in text.split() if word not in cachedStopWords]))
train['Phrasenostopword'] = train.apply(lambda x: removeStopword(x), axis=1)

# %%
train_xword = train['Phrasenostopword'].values.tolist()
vec = TFIDF()
X = vec.fit_transform(train_xword)

# %%
le = preprocessing.LabelEncoder()
y = le.fit_transform(train['category'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state =1)

# %%
clf = MultinomialNB().fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.3908073445652607

# %%
clf.score(X_test,y_test)
# Out:
# 0.3908073445652607

# %%
times = 100
clfcrvs = MultinomialNB()
scores = cross_val_score(clfcrvs, X, y, cv=times)

# %%
#mpl.rcParams['font.sans-serif'] = ['SimHei']
#plt.title('Bayes Model')
#plt.xlabel("Times")
#plt.ylabel("Score")
#plt.plot(range(times), scores)

# %%
#predict

# %%
df_predict = pd.read_json('newsdata.json')

# %%
df_predict
# Out:
#                    id                                              title  \
# 0      127794  191172  Russia and Turkey sign gas deal, seek common g...
# 1      108127  161703  WATCH: Baby Hippo, Born Prematurely, Takes Her...
# 2      100522  148043  Alex Jones retracts false stories about Choban...
# 3       70691  101026   A White Supremacist Is Telling People To Trol...
# 4      142372  213421  ‘A personal slush fundâ€™: The charges against...
# ...       ...     ...                                                ...
# 20995   81008  122161  CC Students Demand Mandatory Diversity Courses...
# 20996   72086  104758   International Leaders Agree To End “Hostiliti...
# 20997  110659  164930  He Called Himself ’One Lucky Bastard’: Sir Rog...
# 20998   73735  110659   Lawyers For Transgender Student Ask Supreme C...
# 20999  108952  162762  President Trump’s Voter Fraud Investigation Is...
#
#            publication                                author       date  \
# 0              Reuters  Olesya Astakhova and Nick Tattersall 2016-10-11
# 1                  NPR                      Camila Domonoske 2017-02-05
# 2             Guardian                                       2017-05-17
# 3        Buzzfeed News                       Tamerra Griffin 2017-05-06
# 4      Washington Post                        Amber Phillips 2016-07-08
# ...                ...                                   ...        ...
# 20995  National Review                       Katherine Timpf 2016-12-20
# 20996    Buzzfeed News                       Claudia Koerner 2016-02-12
# 20997              NPR                           Jacki Lyden 2017-05-23
# 20998    Buzzfeed News                         Chris Geidner 2016-09-14
# 20999              NPR                           Pam Fessler 2017-03-11
#
#          year month                                                url  \
# 0      2016.0  10.0  http://www.reuters.com/article/us-energy-summi...
# 1      2017.0   2.0  http://www.npr.org/sections/thetwo-way/2017/02...
# 2      2017.0   5.0  https://www.theguardian.com/us-news/2017/may/1...
# 3      2017.0   5.0  https://web.archive.org/web/20170506005924/htt...
# 4      2016.0   7.0  https://web.archive.org/web/20160709002000/htt...
# ...       ...   ...                                                ...
# 20995  2016.0  12.0  http://www.nationalreview.com/article/443224/c...
# 20996  2016.0   2.0  https://web.archive.org/web/20160212165656/htt...
# 20997  2017.0   5.0  http://www.npr.org/sections/thetwo-way/2017/05...
# 20998  2016.0   9.0  https://web.archive.org/web/20160914084042/htt...
# 20999  2017.0   3.0  http://www.npr.org/2017/03/11/519709448/presid...
#
#                                                  content
# 0       Turkey and Russia signed an agreement on Mond...
# 1      A baby hippopotamus, born prematurely at the C...
# 2      Rightwing radio host and conspiracy theorist A...
# 3       A white supremacist has been encouraging peop...
# 4           A longtime Democratic congresswoman from ...
# ...                                                  ...
# 20995  A group of students within the San Mateo Commu...
# 20996   U. S. Secretary of State John Kerry announced...
# 20997  The actor Sir Roger Moore has died at 89 after...
# 20998  ’Read the brief in opposition:’] WASHINGTON  —...
# 20999  You might be asking yourself, whatever happene...
#
# [21000 rows x 10 columns]

# %%
def removeStopword(x):
    text = x['title']
    return  str(' '.join([lemmatizer.lemmatize(word).lower() for word in text.split() if word not in cachedStopWords]))
df_predict['Phrasenostopword'] = df_predict.apply(lambda x: removeStopword(x), axis=1)

# %%
xne = vec.transform(df_predict['Phrasenostopword'])

# %%
dir(clf)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_X',
#  '_check_X_y',
#  '_check_alpha',
#  '_count',
#  '_estimator_type',
#  '_get_coef',
#  '_get_intercept',
#  '_get_param_names',
#  '_get_tags',
#  '_init_counters',
#  '_joint_log_likelihood',
#  '_more_tags',
#  '_update_class_log_prior',
#  '_update_feature_log_prob',
#  'alpha',
#  'class_count_',
#  'class_log_prior_',
#  'class_prior',
#  'classes_',
#  'coef_',
#  'feature_count_',
#  'feature_log_prob_',
#  'fit',
#  'fit_prior',
#  'get_params',
#  'intercept_',
#  'n_features_',
#  'partial_fit',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'score',
#  'set_params']

# %%
df_predict['category'] = le.inverse_transform(clf.predict(xne))

# %%
df_predict.to_json('categorized_news_data.json', orient='records')

# %%
df_predict
# Out:
#                    id                                              title  \
# 0      127794  191172  Russia and Turkey sign gas deal, seek common g...
# 1      108127  161703  WATCH: Baby Hippo, Born Prematurely, Takes Her...
# 2      100522  148043  Alex Jones retracts false stories about Choban...
# 3       70691  101026   A White Supremacist Is Telling People To Trol...
# 4      142372  213421  ‘A personal slush fundâ€™: The charges against...
# ...       ...     ...                                                ...
# 20995   81008  122161  CC Students Demand Mandatory Diversity Courses...
# 20996   72086  104758   International Leaders Agree To End “Hostiliti...
# 20997  110659  164930  He Called Himself ’One Lucky Bastard’: Sir Rog...
# 20998   73735  110659   Lawyers For Transgender Student Ask Supreme C...
# 20999  108952  162762  President Trump’s Voter Fraud Investigation Is...
#
#            publication                                author       date  \
# 0              Reuters  Olesya Astakhova and Nick Tattersall 2016-10-11
# 1                  NPR                      Camila Domonoske 2017-02-05
# 2             Guardian                                       2017-05-17
# 3        Buzzfeed News                       Tamerra Griffin 2017-05-06
# 4      Washington Post                        Amber Phillips 2016-07-08
# ...                ...                                   ...        ...
# 20995  National Review                       Katherine Timpf 2016-12-20
# 20996    Buzzfeed News                       Claudia Koerner 2016-02-12
# 20997              NPR                           Jacki Lyden 2017-05-23
# 20998    Buzzfeed News                         Chris Geidner 2016-09-14
# 20999              NPR                           Pam Fessler 2017-03-11
#
#          year month                                                url  \
# 0      2016.0  10.0  http://www.reuters.com/article/us-energy-summi...
# 1      2017.0   2.0  http://www.npr.org/sections/thetwo-way/2017/02...
# 2      2017.0   5.0  https://www.theguardian.com/us-news/2017/may/1...
# 3      2017.0   5.0  https://web.archive.org/web/20170506005924/htt...
# 4      2016.0   7.0  https://web.archive.org/web/20160709002000/htt...
# ...       ...   ...                                                ...
# 20995  2016.0  12.0  http://www.nationalreview.com/article/443224/c...
# 20996  2016.0   2.0  https://web.archive.org/web/20160212165656/htt...
# 20997  2017.0   5.0  http://www.npr.org/sections/thetwo-way/2017/05...
# 20998  2016.0   9.0  https://web.archive.org/web/20160914084042/htt...
# 20999  2017.0   3.0  http://www.npr.org/2017/03/11/519709448/presid...
#
#                                                  content  \
# 0       Turkey and Russia signed an agreement on Mond...
# 1      A baby hippopotamus, born prematurely at the C...
# 2      Rightwing radio host and conspiracy theorist A...
# 3       A white supremacist has been encouraging peop...
# 4           A longtime Democratic congresswoman from ...
# ...                                                  ...
# 20995  A group of students within the San Mateo Commu...
# 20996   U. S. Secretary of State John Kerry announced...
# 20997  The actor Sir Roger Moore has died at 89 after...
# 20998  ’Read the brief in opposition:’] WASHINGTON  —...
# 20999  You might be asking yourself, whatever happene...
#
#                                         Phrasenostopword       category
# 0      russia turkey sign gas deal, seek common groun...       POLITICS
# 1      watch: baby hippo, born prematurely, takes her...  ENTERTAINMENT
# 2      alex jones retracts false story chobani defama...       POLITICS
# 3      a white supremacist is telling people to troll...       POLITICS
# 4      ‘a personal slush fundâ€™: the charge florida ...       POLITICS
# ...                                                  ...            ...
# 20995  cc students demand mandatory diversity courses...       POLITICS
# 20996  international leaders agree to end “hostilitie...       POLITICS
# 20997  he called himself ’one lucky bastard’: sir rog...       POLITICS
# 20998  lawyers for transgender student ask supreme co...       POLITICS
# 20999  president trump’s voter fraud investigation is...       POLITICS
#
# [21000 rows x 12 columns]

# %%
#print all category
list = []
for item in df_predict['category']:
    if item not in list:
        list.append(item)
print(list)
# Out:
# ['POLITICS', 'ENTERTAINMENT', 'CRIME', 'SPORTS', 'WELLNESS', 'BUSINESS', 'TRAVEL', 'PARENTING', 'QUEER VOICES', 'STYLE & BEAUTY', 'THE WORLDPOST', 'FOOD & DRINK', 'BLACK VOICES', 'SCIENCE', 'HOME & LIVING', 'WEDDINGS', 'TECH', 'MEDIA', 'HEALTHY LIVING', 'COMEDY']
